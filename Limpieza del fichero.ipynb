# %%
from pymongo import MongoClient
import pandas as pd
import json as js
import folium

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

db, coll = connectCollection('companies','companies')
pipeline = [
    {"$unwind":"$offices"},
    {"$match":{"$and":[{"offices":{"$not":{"$size":0}}},{"founded_year":{"$gt":2005,"$lte":2011}}]}}
    ]
results = list(coll.aggregate(pipeline))

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#                            _id               name          permalink  \
# 0     52cdef7c4bab8bd675297d91               Geni               geni
# 1     52cdef7c4bab8bd675297d98            Slacker            slacker
# 2     52cdef7c4bab8bd675297d97             Scribd             scribd
# 3     52cdef7c4bab8bd675297d9c            MeetMoi            meetmoi
# 4     52cdef7c4bab8bd675297d9d              Joost              joost
# ...                        ...                ...                ...
# 6369  52cdef7f4bab8bd67529c6e2          MyChances          mychances
# 6370  52cdef7f4bab8bd67529c6ea         Eazeeloans         eazeeloans
# 6371  52cdef7f4bab8bd67529c6e6  OfficialVirtualDJ  officialvirtualdj
# 6372  52cdef7f4bab8bd67529c6f5             Oriact             oriact
# 6373  52cdef7f4bab8bd67529c6f6             Adhunk             adhunk
#
#                                          crunchbase_url  \
# 0                http://www.crunchbase.com/company/geni
# 1             http://www.crunchbase.com/company/slacker
# 2              http://www.crunchbase.com/company/scribd
# 3             http://www.crunchbase.com/company/meetmoi
# 4               http://www.crunchbase.com/company/joost
# ...                                                 ...
# 6369        http://www.crunchbase.com/company/mychances
# 6370       http://www.crunchbase.com/company/eazeeloans
# 6371  http://www.crunchbase.com/company/officialvirt...
# 6372           http://www.crunchbase.com/company/oriact
# 6373           http://www.crunchbase.com/company/adhunk
#
#                                  homepage_url  \
# 0                         http://www.geni.com
# 1                      http://www.slacker.com
# 2                           http://scribd.com
# 3                      http://www.meetmoi.com
# 4                            http://joost.com
# ...                                       ...
# 6369                 http://www.mychances.net
# 6370                http://www.eazeeloans.com
# 6371  http://www.officialvirtualdjmusic.co.uk
# 6372                    http://www.oriact.com
# 6373                    http://www.adhunk.com
#
#                                             blog_url  \
# 0                               http://blog.geni.com
# 1
# 2                            http://blog.scribd.com/
# 3
# 4                              http://blog.joost.com
# ...                                              ...
# 6369                  http://www.mychances.net/blog/
# 6370               http://wwweasyloans.blogspot.com/
# 6371  http://www.officialvirtualdjmusic.blogspot.com
# 6372
# 6373                          http://blog.adhunk.com
#
#                             blog_feed_url twitter_username category_code  \
# 0          http://blog.geni.com/index.rdf             geni           web
# 1                                             SlackerRadio         music
# 2            http://blog.scribd.com/feed/           scribd          news
# 3                                                  meetmoi        social
# 4          http://blog.joost.com/atom.xml             None   games_video
# ...                                   ...              ...           ...
# 6369  http://www.mychances.net/blog/feed/        mychances    consulting
# 6370                                                subu92           web
# 6371                                         VirtualMusics         music
# 6372                                                            software
# 6373          http://blog.adhunk.com/feed                    advertising
#
#       number_of_employees  ...  investments  \
# 0                    18.0  ...           []
# 1                     NaN  ...           []
# 2                    50.0  ...           []
# 3                    15.0  ...           []
# 4                     0.0  ...           []
# ...                   ...  ...          ...
# 6369                  2.0  ...           []
# 6370                 25.0  ...           []
# 6371                102.0  ...           []
# 6372                  NaN  ...           []
# 6373                  3.0  ...           []
#
#                                             acquisition  acquisitions  \
# 0     {'price_amount': None, 'price_currency_code': ...            []
# 1                                                  None            []
# 2                                                  None            []
# 3                                                  None            []
# 4     {'price_amount': None, 'price_currency_code': ...            []
# ...                                                 ...           ...
# 6369  {'price_amount': None, 'price_currency_code': ...            []
# 6370                                               None            []
# 6371                                               None            []
# 6372                                               None            []
# 6373                                               None            []
#
#                                                 offices  \
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 6369  {'description': 'Menlo Park Office', 'address1...
# 6370  {'description': 'Apex Finance & Marketing', 'a...
# 6371  {'description': 'Created in London', 'address1...
# 6372  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373  {'description': 'Indian Office', 'address1': '...
#
#                                              milestones   ipo  \
# 0     [{'id': 15460, 'description': 'Announced hire ...  None
# 1                                                    []  None
# 2     [{'id': 4960, 'description': 'Scribd launches ...  None
# 3                                                    []  None
# 4     [{'id': 4860, 'description': 'Joost Video Netw...  None
# ...                                                 ...   ...
# 6369                                                 []  None
# 6370                                                 []  None
# 6371                                                 []  None
# 6372                                                 []  None
# 6373                                                 []  None
#
#                                            video_embeds  \
# 0     [{'embed_code': '<object width="425" height="3...
# 1                                                    []
# 2     [{'embed_code': '<script src="http://i.cdn.tur...
# 3     [{'embed_code': '<iframe src="http://player.vi...
# 4     [{'embed_code': '<object width="425" height="3...
# ...                                                 ...
# 6369                                                 []
# 6370                                                 []
# 6371                                                 []
# 6372                                                 []
# 6373                                                 []
#
#                                             screenshots  \
# 0                                                    []
# 1                                                    []
# 2     [{'available_sizes': [[[150, 72], 'assets/imag...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 6369  [{'available_sizes': [[[150, 120], 'assets/ima...
# 6370                                                 []
# 6371  [{'available_sizes': [[[136, 106], 'assets/ima...
# 6372                                                 []
# 6373                                                 []
#
#                                          external_links partners
# 0                                                    []       []
# 1                                                    []       []
# 2     [{'external_url': 'http://www.online-tech-tips...       []
# 3     [{'external_url': 'http://www.sociableblog.com...       []
# 4                                                    []       []
# ...                                                 ...      ...
# 6369  [{'external_url': 'http://blogs.wsj.com/juggle...       []
# 6370  [{'external_url': 'http://wwweasyloans.blogspo...       []
# 6371  [{'external_url': 'http://www.officialvirtuald...       []
# 6372  [{'external_url': 'http://origo.ethz.ch', 'tit...       []
# 6373  [{'external_url': 'http://www.hubpages.in/inte...       []
#
# [6374 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url',
#        'blog_url', 'blog_feed_url', 'twitter_username', 'category_code',
#        'number_of_employees', 'founded_year', 'founded_month', 'founded_day',
#        'deadpooled_year', 'deadpooled_month', 'deadpooled_day',
#        'deadpooled_url', 'tag_list', 'alias_list', 'email_address',
#        'phone_number', 'description', 'created_at', 'updated_at', 'overview',
#        'image', 'products', 'relationships', 'competitions', 'providerships',
#        'total_money_raised', 'funding_rounds', 'investments', 'acquisition',
#        'acquisitions', 'offices', 'milestones', 'ipo', 'video_embeds',
#        'screenshots', 'external_links', 'partners'],
#       dtype='object')

# %%
df =df.drop(['permalink', 'crunchbase_url','homepage_url',
       'blog_url','blog_feed_url', 'twitter_username','founded_month', 'founded_day',
        'deadpooled_month', 'deadpooled_day',
       'deadpooled_url', 'tag_list', 'alias_list', 'email_address',
       'phone_number','created_at', 'updated_at', 'overview',
       'image', 'products', 'relationships', 'competitions', 'providerships','investments', 'acquisition',
       'acquisitions','milestones', 'ipo', 'video_embeds',
       'screenshots', 'external_links', 'partners','funding_rounds'], axis = 1)

# %%
df
# Out:
#                            _id               name category_code  \
# 0     52cdef7c4bab8bd675297d91               Geni           web
# 1     52cdef7c4bab8bd675297d98            Slacker         music
# 2     52cdef7c4bab8bd675297d97             Scribd          news
# 3     52cdef7c4bab8bd675297d9c            MeetMoi        social
# 4     52cdef7c4bab8bd675297d9d              Joost   games_video
# ...                        ...                ...           ...
# 6369  52cdef7f4bab8bd67529c6e2          MyChances    consulting
# 6370  52cdef7f4bab8bd67529c6ea         Eazeeloans           web
# 6371  52cdef7f4bab8bd67529c6e6  OfficialVirtualDJ         music
# 6372  52cdef7f4bab8bd67529c6f5             Oriact      software
# 6373  52cdef7f4bab8bd67529c6f6             Adhunk   advertising
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              NaN
# 1                     NaN          2006              NaN
# 2                    50.0          2007              NaN
# 3                    15.0          2007              NaN
# 4                     0.0          2006              NaN
# ...                   ...           ...              ...
# 6369                  2.0          2009              NaN
# 6370                 25.0          2006              NaN
# 6371                102.0          2009           2009.0
# 6372                  NaN          2009              NaN
# 6373                  3.0          2009              NaN
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 6369      College admissions predictions                 $0
# 6370                Loan advisory portal                 $0
# 6371                Virtual Music Player               €25M
# 6372  Solutions for software development                 $0
# 6373                    Online Admanager                 $0
#
#                                                 offices
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 6369  {'description': 'Menlo Park Office', 'address1...
# 6370  {'description': 'Apex Finance & Marketing', 'a...
# 6371  {'description': 'Created in London', 'address1...
# 6372  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373  {'description': 'Indian Office', 'address1': '...
#
# [6374 rows x 9 columns]

# %%
list_category = {'web': 'tech', 'software': 'tech', 
                 'games_video':'tech', 'mobile':'tech', 'ecommerce':'tech', 'search':'tech', 'network_hosting':'tech'
                ,'consulting':'tech','hardware':'tech', 'biotech':'tech', 'cleantech':'tech', 'analytics':'tech','hardware':'tech', 
                'messaging':'tech','nanotech': 'tech'}

# %%
df = df.replace(to_replace=list_category, inplace=False)

# %%
df
# Out:
#                            _id               name category_code  \
# 0     52cdef7c4bab8bd675297d91               Geni          tech
# 1     52cdef7c4bab8bd675297d98            Slacker         music
# 2     52cdef7c4bab8bd675297d97             Scribd          news
# 3     52cdef7c4bab8bd675297d9c            MeetMoi        social
# 4     52cdef7c4bab8bd675297d9d              Joost          tech
# ...                        ...                ...           ...
# 6369  52cdef7f4bab8bd67529c6e2          MyChances          tech
# 6370  52cdef7f4bab8bd67529c6ea         Eazeeloans          tech
# 6371  52cdef7f4bab8bd67529c6e6  OfficialVirtualDJ         music
# 6372  52cdef7f4bab8bd67529c6f5             Oriact          tech
# 6373  52cdef7f4bab8bd67529c6f6             Adhunk   advertising
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              NaN
# 1                     NaN          2006              NaN
# 2                    50.0          2007              NaN
# 3                    15.0          2007              NaN
# 4                     0.0          2006              NaN
# ...                   ...           ...              ...
# 6369                  2.0          2009              NaN
# 6370                 25.0          2006              NaN
# 6371                102.0          2009           2009.0
# 6372                  NaN          2009              NaN
# 6373                  3.0          2009              NaN
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 6369      College admissions predictions                 $0
# 6370                Loan advisory portal                 $0
# 6371                Virtual Music Player               €25M
# 6372  Solutions for software development                 $0
# 6373                    Online Admanager                 $0
#
#                                                 offices
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 6369  {'description': 'Menlo Park Office', 'address1...
# 6370  {'description': 'Apex Finance & Marketing', 'a...
# 6371  {'description': 'Created in London', 'address1...
# 6372  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373  {'description': 'Indian Office', 'address1': '...
#
# [6374 rows x 9 columns]

# %%
list_design={'advertising':'design','photo_video':'design'}

# %%
df = df.replace(to_replace=list_design, inplace=False)

# %%
df
# Out:
#                            _id               name category_code  \
# 0     52cdef7c4bab8bd675297d91               Geni          tech
# 1     52cdef7c4bab8bd675297d98            Slacker         music
# 2     52cdef7c4bab8bd675297d97             Scribd          news
# 3     52cdef7c4bab8bd675297d9c            MeetMoi        social
# 4     52cdef7c4bab8bd675297d9d              Joost          tech
# ...                        ...                ...           ...
# 6369  52cdef7f4bab8bd67529c6e2          MyChances          tech
# 6370  52cdef7f4bab8bd67529c6ea         Eazeeloans          tech
# 6371  52cdef7f4bab8bd67529c6e6  OfficialVirtualDJ         music
# 6372  52cdef7f4bab8bd67529c6f5             Oriact          tech
# 6373  52cdef7f4bab8bd67529c6f6             Adhunk        design
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              NaN
# 1                     NaN          2006              NaN
# 2                    50.0          2007              NaN
# 3                    15.0          2007              NaN
# 4                     0.0          2006              NaN
# ...                   ...           ...              ...
# 6369                  2.0          2009              NaN
# 6370                 25.0          2006              NaN
# 6371                102.0          2009           2009.0
# 6372                  NaN          2009              NaN
# 6373                  3.0          2009              NaN
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 6369      College admissions predictions                 $0
# 6370                Loan advisory portal                 $0
# 6371                Virtual Music Player               €25M
# 6372  Solutions for software development                 $0
# 6373                    Online Admanager                 $0
#
#                                                 offices
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 6369  {'description': 'Menlo Park Office', 'address1...
# 6370  {'description': 'Apex Finance & Marketing', 'a...
# 6371  {'description': 'Created in London', 'address1...
# 6372  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373  {'description': 'Indian Office', 'address1': '...
#
# [6374 rows x 9 columns]

# %%
df["deadpooled_year"].fillna(0, inplace=True)

# %%
df
# Out:
#                            _id               name category_code  \
# 0     52cdef7c4bab8bd675297d91               Geni          tech
# 1     52cdef7c4bab8bd675297d98            Slacker         music
# 2     52cdef7c4bab8bd675297d97             Scribd          news
# 3     52cdef7c4bab8bd675297d9c            MeetMoi        social
# 4     52cdef7c4bab8bd675297d9d              Joost          tech
# ...                        ...                ...           ...
# 6369  52cdef7f4bab8bd67529c6e2          MyChances          tech
# 6370  52cdef7f4bab8bd67529c6ea         Eazeeloans          tech
# 6371  52cdef7f4bab8bd67529c6e6  OfficialVirtualDJ         music
# 6372  52cdef7f4bab8bd67529c6f5             Oriact          tech
# 6373  52cdef7f4bab8bd67529c6f6             Adhunk        design
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              0.0
# 1                     NaN          2006              0.0
# 2                    50.0          2007              0.0
# 3                    15.0          2007              0.0
# 4                     0.0          2006              0.0
# ...                   ...           ...              ...
# 6369                  2.0          2009              0.0
# 6370                 25.0          2006              0.0
# 6371                102.0          2009           2009.0
# 6372                  NaN          2009              0.0
# 6373                  3.0          2009              0.0
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 6369      College admissions predictions                 $0
# 6370                Loan advisory portal                 $0
# 6371                Virtual Music Player               €25M
# 6372  Solutions for software development                 $0
# 6373                    Online Admanager                 $0
#
#                                                 offices
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 6369  {'description': 'Menlo Park Office', 'address1...
# 6370  {'description': 'Apex Finance & Marketing', 'a...
# 6371  {'description': 'Created in London', 'address1...
# 6372  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373  {'description': 'Indian Office', 'address1': '...
#
# [6374 rows x 9 columns]

# %%
df["deadpooled_year"].value_counts()
# Out:
# 0.0       5896
# 2012.0     135
# 2011.0      87
# 2010.0      86
# 2009.0      69
# 2013.0      61
# 2008.0      36
# 2007.0       3
# 2006.0       1
# Name: deadpooled_year, dtype: int64

# %%
df=df[df["deadpooled_year"] == 0]

# %%
df
# Out:
#                            _id        name category_code  number_of_employees  \
# 0     52cdef7c4bab8bd675297d91        Geni          tech                 18.0
# 1     52cdef7c4bab8bd675297d98     Slacker         music                  NaN
# 2     52cdef7c4bab8bd675297d97      Scribd          news                 50.0
# 3     52cdef7c4bab8bd675297d9c     MeetMoi        social                 15.0
# 4     52cdef7c4bab8bd675297d9d       Joost          tech                  0.0
# ...                        ...         ...           ...                  ...
# 6368  52cdef7f4bab8bd67529c6e2   MyChances          tech                  2.0
# 6369  52cdef7f4bab8bd67529c6e2   MyChances          tech                  2.0
# 6370  52cdef7f4bab8bd67529c6ea  Eazeeloans          tech                 25.0
# 6372  52cdef7f4bab8bd67529c6f5      Oriact          tech                  NaN
# 6373  52cdef7f4bab8bd67529c6f6      Adhunk        design                  3.0
#
#       founded_year  deadpooled_year                         description  \
# 0             2006              0.0       Geneology social network site
# 1             2006              0.0         Music Personalization Suite
# 2             2007              0.0                Read Unlimited Books
# 3             2007              0.0                       Mobile Dating
# 4             2006              0.0                                None
# ...            ...              ...                                 ...
# 6368          2009              0.0      College admissions predictions
# 6369          2009              0.0      College admissions predictions
# 6370          2006              0.0                Loan advisory portal
# 6372          2009              0.0  Solutions for software development
# 6373          2009              0.0                    Online Admanager
#
#      total_money_raised                                            offices
# 0                $16.5M  {'description': 'Headquarters', 'address1': '9...
# 1                $73.1M  {'description': '', 'address1': '16935 W. Bern...
# 2                $25.8M  {'description': 'HQ', 'address1': '539 Bryant ...
# 3                $5.58M  {'description': None, 'address1': '', 'address...
# 4                  $45M  {'description': '', 'address1': '100 5th Ave F...
# ...                 ...                                                ...
# 6368                 $0  {'description': 'Headquarters', 'address1': ''...
# 6369                 $0  {'description': 'Menlo Park Office', 'address1...
# 6370                 $0  {'description': 'Apex Finance & Marketing', 'a...
# 6372                 $0  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 6373                 $0  {'description': 'Indian Office', 'address1': '...
#
# [5896 rows x 9 columns]

# %%
# Tengo que intentar sacar las ciudades y los paises

city = []
dat = df["offices"]


for key,value in dat.items():
    city.append(value["city"])

# %%
print(len(city))
# Out:
# 5896

# %%
country = []
for key,value in dat.items():
    country.append(value["country_code"])

# %%
print(len(country))
# Out:
# 5896

# %%
latitud = []
longitud = []
data = df["offices"]

for key,value in data.items():
       latitud.append(value["latitude"])

# %%
print(latitud)
# Out:
# [34.090368, 33.022176, 37.789634, 40.757929, 40.7464969, 37.7768052, 37.778613, 34.017606, 37.788482, 34.1494713, None, None, None, None, 37.78976, 40.726155, 31.046051, 37.392936, None, None, 37.465645, 40.801358, 37.762541, 37.269175, 47.620716, 37.488336, 37.780716, 37.559287, 37.269175, 37.421621, 37.7870842, None, None, 52.3745228, 50.9444598, 47.599925, None, 34.0126379, 37.36965, 37.758113, 37.09024, 37.90077, 48.856667, 48.866323, 37.391502, 37.870744, 37.437328, 37.779507, 42.350571, 32.0554, 37.775196, 40.7143528, 37.796164, 37.775196, 34.184598, 37.782263, 37.905544, 37.766909, 51.514935, 37.6637279, 38.9590083, 51.5170385, None, 40.30305, 37.55909, 37.787092, None, 37.775196, 37.779392, 37.384651, 33.429864, 37.386376, 37.269175, 47.620716, 39.967704, None, None, None, None, None, None, 40.736416, 40.010492, 59.3167843, 39.205649, 40.753631, 42.359146, None, None, None, None, 37.400465, -23.558584, 37.368594, 51.9122575, None, 32.0554, 40.797364, 37.09024, 40.010492, 37.018244, 40.270666, None, 37.09024, 31.046051, 38.892371, None, 38.0729365, 17.08881, 37.09024, 49.263588, 37.7909427, None, None, None, None, None, 37.795555, 37.779507, None, None, None, 37.5646055, 37.786942, 37.7911148, None, 40.010492, 40.0186731, 37.437328, 42.35892, None, 40.751816, None, None, None, 59.3369746, None, None, None, 43.6587599, None, 37.789488, 37.450128, 40.010492, 34.018275, 42.372912, 37.524422, 34.017373, 26.207024, 37.836957, 42.358822, 47.597965, 51.5108803, 12.971606, 41.841713, 37.09024, 59.3339908, None, 35.22806, 42.3729, 37.433414, 51.5192042, 47.5999337, 37.775196, 43.799511, None, 30.386601, 40.723384, None, 40.643438, 37.781265, 40.74406, None, 37.386665, None, None, None, 34.099253, None, 51.5195795, None, 34.031276, 47.611012, 37.563585, 40.753202, 40.775537, None, 37.7749295, None, None, 40.048078, 32.847521, 37.764169, 33.8171, 37.793742, None, 37.446668, None, None, None, 38.003376, 45.5241278, 37.445714, 47.6015315, None, 30.182107, 47.585114, 48.8558532, 41.890376, 47.6104101, 43.67084, 42.375392, 40.01621, 40.7413559, None, None, 36.076705, 51.519819, 42.375392, 37.799549, 37.222604, 33.945553, 40.72948, None, 37.557637, 37.887864, 33.020832, 37.384239, 32.860831, None, 40.740337, 37.789634, 39.530368, 37.369195, 37.8136086, None, -37.797384, 32.0554, 42.364367, 37.904468, None, 34.210785, None, 40.756799, None, 37.401355, 37.792262, 45.500277, 37.396312, None, None, None, 37.775196, 37.39248, 37.862209, 45.3085, 42.354022, None, 28.208654, 32.856744, 37.856331, 53.707739, 40.530724, 37.09024, 37.443058, 37.386175, None, 47.649027, 37.09024, None, 37.782809, 47.5984767, 47.610571, 51.520779, 37.553743, 40.743808, 42.288291, None, 51.54202, None, None, 37.872222, 37.772542, 40.09665, None, None, 37.2572451, 37.388095, 37.590056, 48.8599791, None, 40.741266, 37.787249, 41.8831959, 32.1618634, 48.8743443, 51.5150129, 37.791733, 37.43938, None, None, None, None, 45.545447, 40.757929, None, 37.351894, 39.016745, None, 37.786906, 37.279132, 33.756806, 40.718888, None, None, None, None, 38.977092, 40.755446, None, 50.837051, 42.402378, 52.523402, 40.7550005, 34.064139, 32.0554, 37.794643, None, None, None, 37.838225, 37.09024, 37.781262, 55.6839208, None, 51.5111369, 39.738499, 37.7726402, None, 37.530893, 42.277416, 37.636288, None, None, 37.385216, 37.4069445, 33.971132, 47.620716, 37.09024, 37.872228, None, 47.6018824, 47.603577, None, 43.670233, 42.591704, 37.803847, 52.146853, None, None, None, 33.999004, 41.355252, None, 39.613859, None, 38.984172, None, 40.757929, 49.2753229, None, None, 43.744031, 48.450576, None, None, None, None, 39.935819, 40.7473113, 38.9143473, 31.2006566, None, None, 40.606061, None, 48.8780596, 53.540804, 47.6139472, 26.820375, 37.09024, 36.611645, 40.532457, 37.09024, 33.639318, None, 42.375392, 31.046051, 32.068424, 37.775196, 48.856667, None, None, None, 37.09024, 37.4418834, 37.09024, 37.09024, 37.7749295, 40.740231, 37.40721, 37.775196, None, None, 34.01052, None, 40.74727, 37.0 ...

# %%
longitud = []
for key,value in data.items():
    longitud.append(value["longitude"])

# %%
print(longitud)
# Out:
# [-118.393064, -117.081406, -122.404052, -73.985506, -74.0094471, -122.4169244, -122.395289, -118.487267, -122.409173, -118.1327468, None, None, None, None, -122.402524, -73.995625, 34.851612, -122.07948, None, None, -121.932202, -74.3372, -122.397224, -119.306607, -122.347533, -122.217964, -122.393913, -122.302262, -119.306607, -122.137444, -122.4038047, None, None, 4.8948623, -1.3610845, -122.334264, None, -118.495155, -122.02421, -122.414689, -95.712891, -122.511687, 2.350987, 2.381514, -122.073463, -122.269259, -122.159928, -122.39071, -71.076869, 34.7595, -122.419204, -74.0059731, -122.420903, -122.419204, -118.601532, -122.392142, -122.547445, -122.406676, -0.205349, -121.8731805, -77.3592746, -0.1394759, None, -79.462703, -122.321836, -122.399972, None, -122.419204, -122.417928, -121.992132, -111.944967, -121.991471, -119.306607, -122.347533, -83.005038, None, None, None, None, None, None, -73.993302, -105.276843, 18.1582777, -76.77514, -73.995487, -71.056604, None, None, None, None, -122.073003, -46.679287, -122.034021, 4.5464658, None, 34.7595, -73.97785, -95.712891, -105.276843, -86.463026, -74.761403, None, -95.712891, 34.851612, -77.081732, None, -122.1879633, -96.76492, -95.712891, -123.138565, -122.4084994, None, None, None, None, None, -122.400729, -122.39071, None, None, None, -122.3229235, -122.401245, -122.3954751, None, -105.276843, -105.2762236, -122.159928, -71.05781, None, -73.971655, None, None, None, 18.0580765, None, None, None, -79.5983626, None, -122.397593, -122.205016, -105.276843, -118.495025, -71.118999, -122.265869, -118.453218, -80.157296, -122.286493, -71.104329, -122.151158, -0.1418973, 77.594376, -71.399771, -95.712891, 18.0571198, None, -80.856178, -71.248472, -122.128772, -0.1626103, -122.3276962, -122.419204, -79.348037, None, -97.753739, -74.001704, None, -73.886452, -122.393229, -74.004592, None, -122.084171, None, None, None, -117.572967, None, -0.1065551, None, -118.456806, -122.333523, -122.324621, -73.986771, -73.981709, None, -122.4194155, None, None, -105.38018, -117.274609, -122.402021, -111.9035, -122.421341, None, -122.156579, None, None, None, -79.420926, -122.675448, -122.161247, -122.335943, None, -95.536, -122.084356, 2.3365754, -87.63406, -122.3396627, -83.913153, -71.118487, -105.28131, -73.9912208, None, None, -115.089514, -0.136174, -71.118487, -122.306571, -121.983814, -118.441219, -74.000195, None, -122.285714, -122.26999, -117.077311, -122.012475, -96.9403, None, -73.993127, -122.404052, -119.81439, -122.036849, -122.2966496, None, 175.2604, 34.7595, -71.078978, -122.542491, None, -118.474261, None, -73.976348, None, -122.104099, -122.403486, -73.560084, -121.961396, None, None, None, -122.419204, -122.072612, -122.298168, -122.77941, -71.140762, None, -82.193515, -117.20717, -122.495222, 10.023246, -3.632687, -95.712891, -122.161674, -122.083487, None, -122.346299, -95.712891, None, -122.394354, -122.3331466, -122.341769, -0.10759, -122.300246, -73.983626, -71.52679, None, -0.0558343, None, None, -122.268403, -122.430127, -75.298032, None, None, -122.0341004, -122.08276, -122.347654, 2.3608064, None, -73.990753, -122.3990501, -87.6517774, 34.9341664, 2.3226888, -0.1326786, -122.398398, -122.158804, None, None, None, None, -73.639076, -73.985506, None, -122.085807, -77.023821, None, -122.397672, -121.956295, -84.392198, -74.001169, None, None, None, None, -94.370901, -73.980246, None, 4.367612, -71.288568, 13.398694, -73.9717364, -118.468672, 34.7595, -122.401144, None, None, None, -122.296411, -95.712891, -122.394958, 12.571492, None, -0.1247662, -105.158645, -122.4099154, None, -122.245087, -83.733276, -122.42689, None, None, -121.972128, -121.9797628, -118.455798, -122.347533, -95.712891, -122.244743, None, -122.3355636, -122.335333, None, -79.386755, -71.319348, -122.402468, -1.721287, None, None, None, -118.472297, -72.930855, None, -104.894986, None, -77.095965, None, -73.985506, -123.1208785, None, None, -79.435661, -123.383426, None, None, None, None, -74.9091 ...

# %%
df1 = pd.DataFrame(list(zip(latitud,longitud)), columns =["latitud","longitud"])

# %%
df2=pd.DataFrame(list(zip(city,country)), columns =["city","country"])

# %%
df1
# Out:
#         latitud    longitud
# 0     34.090368 -118.393064
# 1     33.022176 -117.081406
# 2     37.789634 -122.404052
# 3     40.757929  -73.985506
# 4     40.746497  -74.009447
# ...         ...         ...
# 5891  39.394564 -119.812079
# 5892  37.448491 -122.180281
# 5893        NaN         NaN
# 5894  47.088219    8.437163
# 5895        NaN         NaN
#
# [5896 rows x 2 columns]

# %%
df2
# Out:
#                 city country
# 0     West Hollywood     USA
# 1          San Diego     USA
# 2      San Francisco     USA
# 3      New York City     USA
# 4           New York     USA
# ...              ...     ...
# 5891            Reno     USA
# 5892      Menlo Park     USA
# 5893          Mumbai     IND
# 5894      KÃ¼ssnacht     CHE
# 5895         Bikaner     IND
#
# [5896 rows x 2 columns]

# %%
df =df.reset_index()

# %%
df
# Out:
#       index                       _id        name category_code  \
# 0         0  52cdef7c4bab8bd675297d91        Geni          tech
# 1         1  52cdef7c4bab8bd675297d98     Slacker         music
# 2         2  52cdef7c4bab8bd675297d97      Scribd          news
# 3         3  52cdef7c4bab8bd675297d9c     MeetMoi        social
# 4         4  52cdef7c4bab8bd675297d9d       Joost          tech
# ...     ...                       ...         ...           ...
# 5891   6368  52cdef7f4bab8bd67529c6e2   MyChances          tech
# 5892   6369  52cdef7f4bab8bd67529c6e2   MyChances          tech
# 5893   6370  52cdef7f4bab8bd67529c6ea  Eazeeloans          tech
# 5894   6372  52cdef7f4bab8bd67529c6f5      Oriact          tech
# 5895   6373  52cdef7f4bab8bd67529c6f6      Adhunk        design
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              0.0
# 1                     NaN          2006              0.0
# 2                    50.0          2007              0.0
# 3                    15.0          2007              0.0
# 4                     0.0          2006              0.0
# ...                   ...           ...              ...
# 5891                  2.0          2009              0.0
# 5892                  2.0          2009              0.0
# 5893                 25.0          2006              0.0
# 5894                  NaN          2009              0.0
# 5895                  3.0          2009              0.0
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 5891      College admissions predictions                 $0
# 5892      College admissions predictions                 $0
# 5893                Loan advisory portal                 $0
# 5894  Solutions for software development                 $0
# 5895                    Online Admanager                 $0
#
#                                                 offices
# 0     {'description': 'Headquarters', 'address1': '9...
# 1     {'description': '', 'address1': '16935 W. Bern...
# 2     {'description': 'HQ', 'address1': '539 Bryant ...
# 3     {'description': None, 'address1': '', 'address...
# 4     {'description': '', 'address1': '100 5th Ave F...
# ...                                                 ...
# 5891  {'description': 'Headquarters', 'address1': ''...
# 5892  {'description': 'Menlo Park Office', 'address1...
# 5893  {'description': 'Apex Finance & Marketing', 'a...
# 5894  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 5895  {'description': 'Indian Office', 'address1': '...
#
# [5896 rows x 10 columns]

# %%
df3 =pd.concat([df, df1], axis=1)

# %%
df3=pd.concat([df3, df2], axis=1)

# %%
df3
# Out:
#       index                       _id        name category_code  \
# 0         0  52cdef7c4bab8bd675297d91        Geni          tech
# 1         1  52cdef7c4bab8bd675297d98     Slacker         music
# 2         2  52cdef7c4bab8bd675297d97      Scribd          news
# 3         3  52cdef7c4bab8bd675297d9c     MeetMoi        social
# 4         4  52cdef7c4bab8bd675297d9d       Joost          tech
# ...     ...                       ...         ...           ...
# 5891   6368  52cdef7f4bab8bd67529c6e2   MyChances          tech
# 5892   6369  52cdef7f4bab8bd67529c6e2   MyChances          tech
# 5893   6370  52cdef7f4bab8bd67529c6ea  Eazeeloans          tech
# 5894   6372  52cdef7f4bab8bd67529c6f5      Oriact          tech
# 5895   6373  52cdef7f4bab8bd67529c6f6      Adhunk        design
#
#       number_of_employees  founded_year  deadpooled_year  \
# 0                    18.0          2006              0.0
# 1                     NaN          2006              0.0
# 2                    50.0          2007              0.0
# 3                    15.0          2007              0.0
# 4                     0.0          2006              0.0
# ...                   ...           ...              ...
# 5891                  2.0          2009              0.0
# 5892                  2.0          2009              0.0
# 5893                 25.0          2006              0.0
# 5894                  NaN          2009              0.0
# 5895                  3.0          2009              0.0
#
#                              description total_money_raised  \
# 0          Geneology social network site             $16.5M
# 1            Music Personalization Suite             $73.1M
# 2                   Read Unlimited Books             $25.8M
# 3                          Mobile Dating             $5.58M
# 4                                   None               $45M
# ...                                  ...                ...
# 5891      College admissions predictions                 $0
# 5892      College admissions predictions                 $0
# 5893                Loan advisory portal                 $0
# 5894  Solutions for software development                 $0
# 5895                    Online Admanager                 $0
#
#                                                 offices    latitud  \
# 0     {'description': 'Headquarters', 'address1': '9...  34.090368
# 1     {'description': '', 'address1': '16935 W. Bern...  33.022176
# 2     {'description': 'HQ', 'address1': '539 Bryant ...  37.789634
# 3     {'description': None, 'address1': '', 'address...  40.757929
# 4     {'description': '', 'address1': '100 5th Ave F...  40.746497
# ...                                                 ...        ...
# 5891  {'description': 'Headquarters', 'address1': ''...  39.394564
# 5892  {'description': 'Menlo Park Office', 'address1...  37.448491
# 5893  {'description': 'Apex Finance & Marketing', 'a...        NaN
# 5894  {'description': '', 'address1': 'LÃ¤rchenweg 7...  47.088219
# 5895  {'description': 'Indian Office', 'address1': '...        NaN
#
#         longitud            city country
# 0    -118.393064  West Hollywood     USA
# 1    -117.081406       San Diego     USA
# 2    -122.404052   San Francisco     USA
# 3     -73.985506   New York City     USA
# 4     -74.009447        New York     USA
# ...          ...             ...     ...
# 5891 -119.812079            Reno     USA
# 5892 -122.180281      Menlo Park     USA
# 5893         NaN          Mumbai     IND
# 5894    8.437163      KÃ¼ssnacht     CHE
# 5895         NaN         Bikaner     IND
#
# [5896 rows x 14 columns]

# %%
df4 =df3.drop(["index","_id","offices"], axis = 1)

# %%
df4 =df4.dropna()

# %%
# aqui me hice una funcion para limpiarme todo el money raised. Voy a copiar la de Noelia porque consegui hacerlo
# a mi manera. He perdido todo lo que tenia del fin de semana y no tengo tiempo de volverme a pensar la locular
# de regex que hice. Obviamente este comentario cuando suba mi repositorio github en algun sitio lo borro.
import re

def moneyRaise(value):
    dicc_coin = {'CAD': 1.32,'RUB': 63.75, 'EUR': 0.90, 'GBP': 0.77}
    values_money = {'K':1000, 'M':1000000, 'B': 100000000000}
    value_number = float(re.search('[+-]?([0-9]*[.])?[0-9]+', value)[0])
    if value.endswith('B'):
        cambio = value_number*(values_money['B'])
    elif value.endswith('K[k]'):
        cambio = value_number*(values_money['K'])
    elif value.endswith('M'):
        cambio = value_number*(values_money['M'])
    elif value.startswith("C"):
        cambio =  value_number*(dicc_coin['CAD'])
    elif value.startswith("$"):
        cambio =  value_number
    elif value.startswith("€"):
        cambio = value_number*(dicc_coin['EUR'])
    elif value.startswith("£"):
        cambio = value_number*(dicc_coin['GBP'])
    elif value.startswith("r"):
        cambio = value_number*(dicc_coin['RUB'])
    else:
        cambio = value_number
    return int(cambio)

# %%
df4['total_money_raised'] = df4['total_money_raised'].apply(moneyRaise)

# %%
df4
# Out:
#            name category_code  number_of_employees  founded_year  \
# 0          Geni          tech                 18.0          2006
# 2        Scribd          news                 50.0          2007
# 3       MeetMoi        social                 15.0          2007
# 5       Twitter        social               1300.0          2006
# 6      Powerset          tech                 60.0          2006
# ...         ...           ...                  ...           ...
# 5884   InstantQ        design                  3.0          2009
# 5887  acrossair          tech                  6.0          2009
# 5890     Getyoo          tech                 10.0          2009
# 5891  MyChances          tech                  2.0          2009
# 5892  MyChances          tech                  2.0          2009
#
#       deadpooled_year                       description  total_money_raised  \
# 0                 0.0     Geneology social network site            16500000
# 2                 0.0              Read Unlimited Books            25800000
# 3                 0.0                     Mobile Dating             5580000
# 5                 0.0  Real time communication platform        115999999999
# 6                 0.0                                              22500000
# ...               ...                               ...                 ...
# 5884              0.0      Last Minute Restaurant Deals                   0
# 5887              0.0                  iPhone app house                   0
# 5890              0.0              NFC Events Solutions             1130000
# 5891              0.0    College admissions predictions                   0
# 5892              0.0    College admissions predictions                   0
#
#         latitud    longitud            city country
# 0     34.090368 -118.393064  West Hollywood     USA
# 2     37.789634 -122.404052   San Francisco     USA
# 3     40.757929  -73.985506   New York City     USA
# 5     37.776805 -122.416924   San Francisco     USA
# 6     37.778613 -122.395289   San Francisco     USA
# ...         ...         ...             ...     ...
# 5884  37.369195 -122.036849       Sunnyvale     USA
# 5887  51.517742   -0.116537          London     GBR
# 5890  50.839970    4.346472        Brussels     BEL
# 5891  39.394564 -119.812079            Reno     USA
# 5892  37.448491 -122.180281      Menlo Park     USA
#
# [2344 rows x 11 columns]

# %%
df4=df4[df4["total_money_raised"] != 0]

# %%
df4
# Out:
#             name category_code  number_of_employees  founded_year  \
# 0           Geni          tech                 18.0          2006
# 2         Scribd          news                 50.0          2007
# 3        MeetMoi        social                 15.0          2007
# 5        Twitter        social               1300.0          2006
# 6       Powerset          tech                 60.0          2006
# ...          ...           ...                  ...           ...
# 5838    FundRazr        social                  6.0          2008
# 5872   PubliAtis          tech                 10.0          2006
# 5873       Jelli    enterprise                 12.0          2008
# 5874  Tiny Speck          tech                 45.0          2009
# 5890      Getyoo          tech                 10.0          2009
#
#       deadpooled_year                            description  \
# 0                 0.0          Geneology social network site
# 2                 0.0                   Read Unlimited Books
# 3                 0.0                          Mobile Dating
# 5                 0.0       Real time communication platform
# 6                 0.0
# ...               ...                                    ...
# 5838              0.0                   Social Commerce Apps
# 5872              0.0  SaaS Professional Publishing Software
# 5873              0.0                  User-controlled radio
# 5874              0.0
# 5890              0.0                   NFC Events Solutions
#
#       total_money_raised    latitud    longitud            city country
# 0               16500000  34.090368 -118.393064  West Hollywood     USA
# 2               25800000  37.789634 -122.404052   San Francisco     USA
# 3                5580000  40.757929  -73.985506   New York City     USA
# 5           115999999999  37.776805 -122.416924   San Francisco     USA
# 6               22500000  37.778613 -122.395289   San Francisco     USA
# ...                  ...        ...         ...             ...     ...
# 5838                 429  49.284394 -123.109262       Vancouver     CAN
# 5872             1000000  48.869995    2.340695           PARIS     FRA
# 5873            16600000  37.559090 -122.321836       San Mateo     USA
# 5874            17200000  49.282455 -123.109217       Vancouver     CAN
# 5890             1130000  50.839970    4.346472        Brussels     BEL
#
# [864 rows x 11 columns]

# %%
df4["country"].value_counts()
# Out:
# USA    644
# GBR     44
# FRA     26
# CAN     20
# DEU     18
# ESP     17
# IND     11
# NLD      9
# ISR      8
# SWE      8
# SGP      6
# AUS      6
# DNK      6
# BEL      4
# BRA      4
# CHE      4
# ITA      4
# FIN      3
# IRL      3
# MEX      2
# SVN      2
# CZE      2
# HUN      2
# HRV      2
# BGD      2
# COL      1
# NZL      1
# LUX      1
# ARG      1
# ARE      1
# BGR      1
# EST      1
# Name: country, dtype: int64

# %%
display(df4["city"].value_counts())
# Out:
# San Francisco    129
# New York          77
# London            35
# Seattle           22
# Mountain View     22
#                 ...
# Baltimore          1
# North Haven        1
# Bloomington        1
# Boulogne           1
# Buenos Aires       1
# Name: city, Length: 265, dtype: int64

# %%
from pymongo import MongoClient
import pandas as pd
import json as js

mongo_client = MongoClient('localhost', 27017)

# create new database and client collection
db= mongo_client["companies"]

db.create_collection("business")
# Out:
# ---------------------------------------------------------------------------
# CollectionInvalid                         Traceback (most recent call last)
# <ipython-input-151-e8b81f4e1085> in <module>
#       8 db= mongo_client["companies"]
#       9
# ---> 10 db.create_collection("business")
#
# ~/.local/lib/python3.7/site-packages/pymongo/database.py in create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, **kwargs)
#     405             if name in self.list_collection_names(
#     406                     filter={"name": name}, session=s):
# --> 407                 raise CollectionInvalid("collection %s already exists" % name)
#     408
#     409             return Collection(self, name, True, codec_options,
#
# CollectionInvalid: collection business already exists

# %%
df4.to_csv("business")

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

db, coll = connectCollection('companies','business')

empresas = list(coll.find())

# %%
empresas
# Out:
# [{'_id': ObjectId('5dd411dbec196ddbed90089b'),
#   '': 0,
#   'name': 'Geni',
#   'category_code': 'tech',
#   'number_of_employees': 18.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Geneology social network site',
#   'total_money_raised': 16500000,
#   'latitud': 34.090368,
#   'longitud': -118.393064,
#   'city': 'West Hollywood',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90089c'),
#   '': 6,
#   'name': 'Powerset',
#   'category_code': 'tech',
#   'number_of_employees': 60.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 22500000,
#   'latitud': 37.778613,
#   'longitud': -122.395289,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90089d'),
#   '': 17,
#   'name': 'Ustream',
#   'category_code': 'tech',
#   'number_of_employees': 250.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Live Social Video Community',
#   'total_money_raised': 60100000,
#   'latitud': 37.392936,
#   'longitud': -122.07948,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90089e'),
#   '': 20,
#   'name': 'GrandCentral',
#   'category_code': 'tech',
#   'number_of_employees': 3.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 4000000,
#   'latitud': 37.465645,
#   'longitud': -121.932202,
#   'city': 'Fremont',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90089f'),
#   '': 21,
#   'name': 'AdaptiveBlue',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 24000000,
#   'latitud': 40.801358,
#   'longitud': -74.3372,
#   'city': 'NYC',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a0'),
#   '': 25,
#   'name': 'Spock',
#   'category_code': 'tech',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Search Engine Utilizing Social Media',
#   'total_money_raised': 7000000,
#   'latitud': 37.488336,
#   'longitud': -122.217964,
#   'city': 'SCHUYLER LAKE',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a1'),
#   '': 26,
#   'name': 'CastTV',
#   'category_code': 'tech',
#   'number_of_employees': 0.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 3100000,
#   'latitud': 37.780716,
#   'longitud': -122.393913,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a2'),
#   '': 28,
#   'name': 'SodaHead',
#   'category_code': 'tech',
#   'number_of_employees': 25.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Online Community and Discussion',
#   'total_money_raised': 12700000,
#   'latitud': 37.269175,
#   'longitud': -119.306607,
#   'city': 'Encino',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a3'),
#   '': 30,
#   'name': 'Mashery',
#   'category_code': 'enterprise',
#   'number_of_employees': 0.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'API and developer services',
#   'total_money_raised': 34700000,
#   'latitud': 37.7870842,
#   'longitud': -122.4038047,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a4'),
#   '': 33,
#   'name': 'Wakoopa',
#   'category_code': 'tech',
#   'number_of_employees': 8.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Social network for desktop software',
#   'total_money_raised': 1000000,
#   'latitud': 52.3745228,
#   'longitud': 4.8948623,
#   'city': 'Amsterdam',
#   'country': 'NLD'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a5'),
#   '': 15,
#   'name': 'Livestream',
#   'category_code': 'tech',
#   'number_of_employees': 120.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Live streaming platform and website',
#   'total_money_raised': 14700000,
#   'latitud': 40.726155,
#   'longitud': -73.995625,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a6'),
#   '': 46,
#   'name': 'Terabitz',
#   'category_code': 'tech',
#   'number_of_employees': 12.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 10000000,
#   'latitud': 37.437328,
#   'longitud': -122.159928,
#   'city': 'Palo Alto',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a7'),
#   '': 39,
#   'name': 'Pageflakes',
#   'category_code': 'tech',
#   'number_of_employees': 20.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'AJAX Homepage Service',
#   'total_money_raised': 4099999,
#   'latitud': 37.758113,
#   'longitud': -122.414689,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a8'),
#   '': 47,
#   'name': 'Eventbrite',
#   'category_code': 'tech',
#   'number_of_employees': 200.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online event management & ticketing',
#   'total_money_raised': 140000000,
#   'latitud': 37.779507,
#   'longitud': -122.39071,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008a9'),
#   '': 3,
#   'name': 'MeetMoi',
#   'category_code': 'social',
#   'number_of_employees': 15.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Mobile Dating',
#   'total_money_raised': 5580000,
#   'latitud': 40.757929,
#   'longitud': -73.985506,
#   'city': 'New York City',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008aa'),
#   '': 48,
#   'name': 'Carbonite',
#   'category_code': 'tech',
#   'number_of_employees': 68.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 66000000,
#   'latitud': 42.350571,
#   'longitud': -71.076869,
#   'city': 'Boston',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ab'),
#   '': 50,
#   'name': 'GigaOM',
#   'category_code': 'news',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 14300000,
#   'latitud': 37.775196,
#   'longitud': -122.419204,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ac'),
#   '': 55,
#   'name': 'GoingOn',
#   'category_code': 'tech',
#   'number_of_employees': 40.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Private Academic Networks',
#   'total_money_raised': 8500000,
#   'latitud': 37.782263,
#   'longitud': -122.392142,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ad'),
#   '': 53,
#   'name': 'Seesmic',
#   'category_code': 'tech',
#   'number_of_employees': 13.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Social software applications',
#   'total_money_raised': 16000000,
#   'latitud': 37.775196,
#   'longitud': -122.419204,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ae'),
#   '': 51,
#   'name': 'GigaOM',
#   'category_code': 'news',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 14300000,
#   'latitud': 40.7143528,
#   'longitud': -74.0059731,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008af'),
#   '': 7,
#   'name': 'Mahalo',
#   'category_code': 'tech',
#   'number_of_employees': 40.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Life long learning content',
#   'total_money_raised': 21000000,
#   'latitud': 34.017606,
#   'longitud': -118.487267,
#   'city': 'Culver City',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b0'),
#   '': 2,
#   'name': 'Scribd',
#   'category_code': 'news',
#   'number_of_employees': 50.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Read Unlimited Books',
#   'total_money_raised': 25800000,
#   'latitud': 37.789634,
#   'longitud': -122.404052,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b1'),
#   '': 8,
#   'name': 'Kyte',
#   'category_code': 'tech',
#   'number_of_employees': 40.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online & Mobile Video Platform',
#   'total_money_raised': 23400000,
#   'latitud': 37.788482,
#   'longitud': -122.409173,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b2'),
#   '': 5,
#   'name': 'Twitter',
#   'category_code': 'social',
#   'number_of_employees': 1300.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Real time communication platform',
#   'total_money_raised': 115999999999,
#   'latitud': 37.7768052,
#   'longitud': -122.4169244,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b3'),
#   '': 9,
#   'name': 'OpenX',
#   'category_code': 'design',
#   'number_of_employees': 305.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'OpenX',
#   'total_money_raised': 75500000,
#   'latitud': 34.1494713,
#   'longitud': -118.1327468,
#   'city': 'Pasadena',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b4'),
#   '': 57,
#   'name': 'Flixster',
#   'category_code': 'tech',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Movie social networking',
#   'total_money_raised': 7180000,
#   'latitud': 37.766909,
#   'longitud': -122.406676,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b5'),
#   '': 59,
#   'name': 'spigit',
#   'category_code': 'tech',
#   'number_of_employees': 120.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Purpose-built social networking platform',
#   'total_money_raised': 55600000,
#   'latitud': 37.6637279,
#   'longitud': -121.8731805,
#   'city': 'Pleasanton',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b6'),
#   '': 60,
#   'name': 'spigit',
#   'category_code': 'tech',
#   'number_of_employees': 120.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Purpose-built social networking platform',
#   'total_money_raised': 55600000,
#   'latitud': 38.9590083,
#   'longitud': -77.3592746,
#   'city': 'Reston',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b7'),
#   '': 61,
#   'name': 'spigit',
#   'category_code': 'tech',
#   'number_of_employees': 120.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Purpose-built social networking platform',
#   'total_money_raised': 55600000,
#   'latitud': 51.5170385,
#   'longitud': -0.1394759,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b8'),
#   '': 64,
#   'name': 'Respectance',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '#RIP',
#   'total_money_raised': 1750000,
#   'latitud': 37.55909,
#   'longitud': -122.321836,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008b9'),
#   '': 65,
#   'name': 'Curse',
#   'category_code': 'tech',
#   'number_of_employees': 58.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online games media company',
#   'total_money_raised': 12000000,
#   'latitud': 37.787092,
#   'longitud': -122.399972,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ba'),
#   '': 67,
#   'name': 'Grockit',
#   'category_code': 'social',
#   'number_of_employees': 25.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online social learning games',
#   'total_money_raised': 44700000,
#   'latitud': 37.775196,
#   'longitud': -122.419204,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008bb'),
#   '': 73,
#   'name': 'Wishpot',
#   'category_code': 'tech',
#   'number_of_employees': 10.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Social shopping service',
#   'total_money_raised': 1300000,
#   'latitud': 47.620716,
#   'longitud': -122.347533,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008bc'),
#   '': 82,
#   'name': 'IntenseDebate',
#   'category_code': 'tech',
#   'number_of_employees': 4.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Blog commenting system',
#   'total_money_raised': 515,
#   'latitud': 40.010492,
#   'longitud': -105.276843,
#   'city': 'Boulder',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008bd'),
#   '': 83,
#   'name': 'Rebtel',
#   'category_code': 'tech',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Talk More With Your Loved Ones',
#   'total_money_raised': 20000000,
#   'latitud': 59.3167843,
#   'longitud': 18.1582777,
#   'city': 'Nacka Strand',
#   'country': 'SWE'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008be'),
#   '': 85,
#   'name': 'Lotame',
#   'category_code': 'design',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Data Management Platform',
#   'total_money_raised': 34000000,
#   'latitud': 40.753631,
#   'longitud': -73.995487,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008bf'),
#   '': 86,
#   'name': 'Lotame',
#   'category_code': 'design',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Data Management Platform',
#   'total_money_raised': 34000000,
#   'latitud': 42.359146,
#   'longitud': -71.056604,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c0'),
#   '': 91,
#   'name': 'Buxfer',
#   'category_code': 'tech',
#   'number_of_employees': 4.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 315,
#   'latitud': 37.400465,
#   'longitud': -122.073003,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c1'),
#   '': 92,
#   'name': 'boo-box',
#   'category_code': 'design',
#   'number_of_employees': 50.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'blogs, niche websites & social profiles',
#   'total_money_raised': 300,
#   'latitud': -23.558584,
#   'longitud': -46.679287,
#   'city': 'Sao Paulo',
#   'country': 'BRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c2'),
#   '': 101,
#   'name': 'Scrybe',
#   'category_code': 'enterprise',
#   'number_of_employees': 20.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 1310000,
#   'latitud': 40.270666,
#   'longitud': -74.761403,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c3'),
#   '': 107,
#   'name': 'Echo',
#   'category_code': 'enterprise',
#   'number_of_employees': 50.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Real-time Web Platform',
#   'total_money_raised': 4800000,
#   'latitud': 38.0729365,
#   'longitud': -122.1879633,
#   'city': 'San francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c4'),
#   '': 111,
#   'name': 'Dropbox',
#   'category_code': 'tech',
#   'number_of_employees': 350.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Always have your stuff, wherever you are',
#   'total_money_raised': 257000000,
#   'latitud': 37.7909427,
#   'longitud': -122.4084994,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c5'),
#   '': 117,
#   'name': 'Weebly',
#   'category_code': 'tech',
#   'number_of_employees': 70.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Easiest Way to Create a Website',
#   'total_money_raised': 670,
#   'latitud': 37.795555,
#   'longitud': -122.400729,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c6'),
#   '': 122,
#   'name': 'Inneractive',
#   'category_code': 'design',
#   'number_of_employees': 0.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 8500000,
#   'latitud': 37.5646055,
#   'longitud': -122.3229235,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c7'),
#   '': 123,
#   'name': 'Kongregate',
#   'category_code': 'tech',
#   'number_of_employees': 20.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Gaming social network',
#   'total_money_raised': 19000000,
#   'latitud': 37.786942,
#   'longitud': -122.401245,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c8'),
#   '': 84,
#   'name': 'Lotame',
#   'category_code': 'design',
#   'number_of_employees': 75.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Data Management Platform',
#   'total_money_raised': 34000000,
#   'latitud': 39.205649,
#   'longitud': -76.77514,
#   'city': 'Columbia',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008c9'),
#   '': 124,
#   'name': 'Yola',
#   'category_code': 'tech',
#   'number_of_employees': 70.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Free Websites',
#   'total_money_raised': 25000000,
#   'latitud': 37.7911148,
#   'longitud': -122.3954751,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ca'),
#   '': 118,
#   'name': 'TokBox',
#   'category_code': 'tech',
#   'number_of_employees': 55.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Web video communications platform',
#   'total_money_raised': 26000000,
#   'latitud': 37.779507,
#   'longitud': -122.39071,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008cb'),
#   '': 94,
#   'name': 'Nimbuzz',
#   'category_code': 'tech',
#   'number_of_employees': 140.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Mobile messaging, VoIP and Social',
#   'total_money_raised': 25000000,
#   'latitud': 51.9122575,
#   'longitud': 4.5464658,
#   'city': 'Capelle a/d IJssel',
#   'country': 'NLD'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008cc'),
#   '': 126,
#   'name': 'Filtrbox',
#   'category_code': 'tech',
#   'number_of_employees': 14.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'social media monitoring & analytics',
#   'total_money_raised': 1920000,
#   'latitud': 40.010492,
#   'longitud': -105.276843,
#   'city': 'Palo Alto',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008cd'),
#   '': 129,
#   'name': 'Cloudant',
#   'category_code': 'enterprise',
#   'number_of_employees': 70.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'NoSQL database managed service',
#   'total_money_raised': 18300000,
#   'latitud': 42.35892,
#   'longitud': -71.05781,
#   'city': 'Boston',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ce'),
#   '': 127,
#   'name': 'Socialthing',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 415,
#   'latitud': 40.0186731,
#   'longitud': -105.2762236,
#   'city': 'Boulder',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008cf'),
#   '': 131,
#   'name': 'KIT digital',
#   'category_code': 'enterprise',
#   'number_of_employees': 200.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'video distribution solutions',
#   'total_money_raised': 20000000,
#   'latitud': 40.751816,
#   'longitud': -73.971655,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d0'),
#   '': 149,
#   'name': 'TubeMogul',
#   'category_code': 'design',
#   'number_of_employees': 230.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Video Ad Buying Platform',
#   'total_money_raised': 53200000,
#   'latitud': 37.836957,
#   'longitud': -122.286493,
#   'city': 'Emeryville',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d1'),
#   '': 143,
#   'name': 'Techstars',
#   'category_code': 'finance',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Seed fund + accelerator',
#   'total_money_raised': 34000000,
#   'latitud': 40.010492,
#   'longitud': -105.276843,
#   'city': 'Boulder',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d2'),
#   '': 162,
#   'name': 'EyeJot',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 1150000,
#   'latitud': 47.5999337,
#   'longitud': -122.3276962,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d3'),
#   '': 167,
#   'name': 'OMGPOP',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Free online multiplayer game',
#   'total_money_raised': 16600000,
#   'latitud': 40.723384,
#   'longitud': -74.001704,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d4'),
#   '': 169,
#   'name': 'Daylife',
#   'category_code': 'enterprise',
#   'number_of_employees': 25.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Content Service Provider',
#   'total_money_raised': 12300000,
#   'latitud': 40.643438,
#   'longitud': -73.886452,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d5'),
#   '': 135,
#   'name': 'KIT digital',
#   'category_code': 'enterprise',
#   'number_of_employees': 200.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'video distribution solutions',
#   'total_money_raised': 20000000,
#   'latitud': 59.3369746,
#   'longitud': 18.0580765,
#   'city': 'Stockholm',
#   'country': 'SWE'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d6'),
#   '': 150,
#   'name': 'LocaModa',
#   'category_code': 'design',
#   'number_of_employees': 0.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Place-based social media',
#   'total_money_raised': 7900000,
#   'latitud': 42.358822,
#   'longitud': -71.104329,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d7'),
#   '': 139,
#   'name': 'KIT digital',
#   'category_code': 'enterprise',
#   'number_of_employees': 200.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'video distribution solutions',
#   'total_money_raised': 20000000,
#   'latitud': 43.6587599,
#   'longitud': -79.5983626,
#   'city': 'Mississauga, Ontario',
#   'country': 'CAN'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d8'),
#   '': 144,
#   'name': 'Docstoc',
#   'category_code': 'tech',
#   'number_of_employees': 40.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'The Online Resource for Small Businesses',
#   'total_money_raised': 4000000,
#   'latitud': 34.018275,
#   'longitud': -118.495025,
#   'city': 'Santa Monica',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008d9'),
#   '': 152,
#   'name': 'Seedcamp',
#   'category_code': 'finance',
#   'number_of_employees': 4.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Startup accelerator',
#   'total_money_raised': 5000000,
#   'latitud': 51.5108803,
#   'longitud': -0.1418973,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008da'),
#   '': 170,
#   'name': 'Crunchyroll',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Digital Entertainment and Media Platform',
#   'total_money_raised': 4800000,
#   'latitud': 37.781265,
#   'longitud': -122.393229,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008db'),
#   '': 141,
#   'name': 'Zivity',
#   'category_code': 'tech',
#   'number_of_employees': 16.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Adult photography and art',
#   'total_money_raised': 8000000,
#   'latitud': 37.789488,
#   'longitud': -122.397593,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008dc'),
#   '': 171,
#   'name': 'Behance',
#   'category_code': 'tech',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 6500000,
#   'latitud': 40.74406,
#   'longitud': -74.004592,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008dd'),
#   '': 181,
#   'name': 'hulu',
#   'category_code': 'tech',
#   'number_of_employees': 153.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Online Video Provider',
#   'total_money_raised': 100000000,
#   'latitud': 34.031276,
#   'longitud': -118.456806,
#   'city': 'Los Angeles',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008de'),
#   '': 173,
#   'name': 'Ooyala',
#   'category_code': 'tech',
#   'number_of_employees': 300.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Video streaming, analytics, monetization',
#   'total_money_raised': 122000000,
#   'latitud': 37.386665,
#   'longitud': -122.084171,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008df'),
#   '': 185,
#   'name': 'OrganizedWisdom',
#   'category_code': 'other',
#   'number_of_employees': 18.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Expert-driven platform for health',
#   'total_money_raised': 2800000,
#   'latitud': 40.775537,
#   'longitud': -73.981709,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e0'),
#   '': 187,
#   'name': 'BeFunky',
#   'category_code': 'design',
#   'number_of_employees': 6.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Photo Editing Tools for Web and Mobile',
#   'total_money_raised': 1650000,
#   'latitud': 37.7749295,
#   'longitud': -122.4194155,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e1'),
#   '': 191,
#   'name': 'app2you',
#   'category_code': 'tech',
#   'number_of_employees': 4.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Web applicatoin builder',
#   'total_money_raised': 169,
#   'latitud': 32.847521,
#   'longitud': -117.274609,
#   'city': 'La Jolla',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e2'),
#   '': 202,
#   'name': 'GlobalMotion',
#   'category_code': 'travel',
#   'number_of_employees': 0.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 1000000,
#   'latitud': 37.445714,
#   'longitud': -122.161247,
#   'city': 'Palo Alto',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e3'),
#   '': 196,
#   'name': 'PubMatic',
#   'category_code': 'design',
#   'number_of_employees': 380.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Sell-Side Platform',
#   'total_money_raised': 63000000,
#   'latitud': 37.446668,
#   'longitud': -122.156579,
#   'city': 'Redwood City',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e4'),
#   '': 208,
#   'name': 'Viewpoints',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'User Reviews of Consumer Products',
#   'total_money_raised': 5000000,
#   'latitud': 41.890376,
#   'longitud': -87.63406,
#   'city': 'Chicago',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e5'),
#   '': 211,
#   'name': 'UpDown',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Investment Social Network',
#   'total_money_raised': 1750000,
#   'latitud': 42.375392,
#   'longitud': -71.118487,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e6'),
#   '': 212,
#   'name': 'OneRiot',
#   'category_code': 'design',
#   'number_of_employees': 32.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Advertising Network for Twitter Apps',
#   'total_money_raised': 27300000,
#   'latitud': 40.01621,
#   'longitud': -105.28131,
#   'city': 'Boulder',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e7'),
#   '': 217,
#   'name': 'Webjam',
#   'category_code': 'enterprise',
#   'number_of_employees': 18.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Social Media Solutions',
#   'total_money_raised': 2000000,
#   'latitud': 51.519819,
#   'longitud': -0.136174,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e8'),
#   '': 218,
#   'name': 'GamerDNA',
#   'category_code': 'tech',
#   'number_of_employees': 13.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Social networking for gamers',
#   'total_money_raised': 3000000,
#   'latitud': 42.375392,
#   'longitud': -71.118487,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008e9'),
#   '': 213,
#   'name': 'Clickable',
#   'category_code': 'design',
#   'number_of_employees': 160.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Solution for online advertisers.',
#   'total_money_raised': 32500000,
#   'latitud': 40.7413559,
#   'longitud': -73.9912208,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ea'),
#   '': 203,
#   'name': 'FlowPlay',
#   'category_code': 'tech',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Virtual world technology and games',
#   'total_money_raised': 3970000,
#   'latitud': 47.6015315,
#   'longitud': -122.335943,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008eb'),
#   '': 192,
#   'name': 'TripIt',
#   'category_code': 'travel',
#   'number_of_employees': 63.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Organize Your Travel',
#   'total_money_raised': 13100000,
#   'latitud': 37.764169,
#   'longitud': -122.402021,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ec'),
#   '': 206,
#   'name': 'Feedjit',
#   'category_code': 'tech',
#   'number_of_employees': 2.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 450,
#   'latitud': 47.585114,
#   'longitud': -122.084356,
#   'city': 'Sammamish',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ed'),
#   '': 193,
#   'name': 'GENWI',
#   'category_code': 'tech',
#   'number_of_employees': 25.0,
#   'founded_year': 2010,
#   'deadpooled_year': 0.0,
#   'description': 'Cloud Publishing for Mobile',
#   'total_money_raised': 7100000,
#   'latitud': 33.8171,
#   'longitud': -111.9035,
#   'city': 'Los Altos',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ee'),
#   '': 194,
#   'name': 'YourStreet',
#   'category_code': 'tech',
#   'number_of_employees': 6.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 250,
#   'latitud': 37.793742,
#   'longitud': -122.421341,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ef'),
#   '': 222,
#   'name': 'Animoto',
#   'category_code': 'music',
#   'number_of_employees': 60.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Animated slide-show generator',
#   'total_money_raised': 30000000,
#   'latitud': 40.72948,
#   'longitud': -74.000195,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f0'),
#   '': 200,
#   'name': 'Mixx',
#   'category_code': 'tech',
#   'number_of_employees': 11.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Social Network and Media sharing',
#   'total_money_raised': 3500000,
#   'latitud': 38.003376,
#   'longitud': -79.420926,
#   'city': 'McLean',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f1'),
#   '': 226,
#   'name': 'Metaplace',
#   'category_code': 'tech',
#   'number_of_employees': 12.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 9400000,
#   'latitud': 33.020832,
#   'longitud': -117.077311,
#   'city': 'Solana Beach',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f2'),
#   '': 224,
#   'name': 'SpeedDate',
#   'category_code': 'tech',
#   'number_of_employees': 0.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 11600000,
#   'latitud': 37.557637,
#   'longitud': -122.285714,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f3'),
#   '': 231,
#   'name': 'Xobni',
#   'category_code': 'tech',
#   'number_of_employees': 0.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Email and contact management platform.',
#   'total_money_raised': 41800000,
#   'latitud': 37.789634,
#   'longitud': -122.404052,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f4'),
#   '': 245,
#   'name': 'SueEasy',
#   'category_code': 'tech',
#   'number_of_employees': 6.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'First & Largest Class Action Repository',
#   'total_money_raised': 135,
#   'latitud': 37.401355,
#   'longitud': -122.104099,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f5'),
#   '': 270,
#   'name': 'The Climate Corporation',
#   'category_code': 'tech',
#   'number_of_employees': 150.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Tackling climate change through tech.',
#   'total_money_raised': 109000000,
#   'latitud': 37.782809,
#   'longitud': -122.394354,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f6'),
#   '': 243,
#   'name': 'Worklight',
#   'category_code': 'tech',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'mobile application platform software',
#   'total_money_raised': 17600000,
#   'latitud': 40.756799,
#   'longitud': -73.976348,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f7'),
#   '': 265,
#   'name': 'Polyvore',
#   'category_code': 'tech',
#   'number_of_employees': 73.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Social Shopping Platform',
#   'total_money_raised': 22100000,
#   'latitud': 37.386175,
#   'longitud': -122.083487,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f8'),
#   '': 260,
#   'name': 'Whiskey Media',
#   'category_code': 'tech',
#   'number_of_employees': 12.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'websites development',
#   'total_money_raised': 4000000,
#   'latitud': 37.856331,
#   'longitud': -122.495222,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008f9'),
#   '': 262,
#   'name': 'Fon',
#   'category_code': 'tech',
#   'number_of_employees': 100.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Your global WiFi network',
#   'total_money_raised': 44000000,
#   'latitud': 40.530724,
#   'longitud': -3.632687,
#   'city': 'Madrid',
#   'country': 'ESP'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008fa'),
#   '': 268,
#   'name': '23andMe',
#   'category_code': 'tech',
#   'number_of_employees': 80.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'human genome indexing/application',
#   'total_money_raised': 161000000,
#   'latitud': 37.09024,
#   'longitud': -95.712891,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008fb'),
#   '': 267,
#   'name': 'AdReady',
#   'category_code': 'design',
#   'number_of_employees': 33.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Advertising technology company',
#   'total_money_raised': 17800000,
#   'latitud': 47.649027,
#   'longitud': -122.346299,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008fc'),
#   '': 274,
#   'name': 'Veodia',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Enterprise Video Service',
#   'total_money_raised': 8300000,
#   'latitud': 37.553743,
#   'longitud': -122.300246,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008fd'),
#   '': 271,
#   'name': 'The Climate Corporation',
#   'category_code': 'tech',
#   'number_of_employees': 150.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Tackling climate change through tech.',
#   'total_money_raised': 109000000,
#   'latitud': 47.5984767,
#   'longitud': -122.3331466,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008fe'),
#   '': 286,
#   'name': 'Rollbase',
#   'category_code': 'enterprise',
#   'number_of_employees': 0.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Platform as a Service',
#   'total_money_raised': 300,
#   'latitud': 37.2572451,
#   'longitud': -122.0341004,
#   'city': 'Saratoga',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed9008ff'),
#   '': 276,
#   'name': 'uTest',
#   'category_code': 'tech',
#   'number_of_employees': 120.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'In-the-wild software testing',
#   'total_money_raised': 37800000,
#   'latitud': 42.288291,
#   'longitud': -71.52679,
#   'city': 'Framingham',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900900'),
#   '': 288,
#   'name': 'BitGravity',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Video Delivery Network',
#   'total_money_raised': 2500000,
#   'latitud': 37.590056,
#   'longitud': -122.347654,
#   'city': 'Burlingame',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900901'),
#   '': 287,
#   'name': 'TrialPay',
#   'category_code': 'design',
#   'number_of_employees': 100.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Product and service barter marketplace',
#   'total_money_raised': 55800000,
#   'latitud': 37.388095,
#   'longitud': -122.08276,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900902'),
#   '': 309,
#   'name': 'Disqus',
#   'category_code': 'tech',
#   'number_of_employees': 43.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': "The Web's Community of Communities",
#   'total_money_raised': 10500000,
#   'latitud': 37.786906,
#   'longitud': -122.397672,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900903'),
#   '': 298,
#   'name': 'Gigya',
#   'category_code': 'enterprise',
#   'number_of_employees': 230.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Connected Consumer Management Suite',
#   'total_money_raised': 69800000,
#   'latitud': 37.43938,
#   'longitud': -122.158804,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900904'),
#   '': 332,
#   'name': 'Dipity',
#   'category_code': 'tech',
#   'number_of_employees': 4.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 900,
#   'latitud': 37.781262,
#   'longitud': -122.394958,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900905'),
#   '': 330,
#   'name': 'RepairPal',
#   'category_code': 'tech',
#   'number_of_employees': 25.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Online Auto Repair Estimates',
#   'total_money_raised': 21300000,
#   'latitud': 37.838225,
#   'longitud': -122.296411,
#   'city': 'Emeryville',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900906'),
#   '': 322,
#   'name': 'Plazes',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Location Based Microblogging',
#   'total_money_raised': 3700000,
#   'latitud': 52.523402,
#   'longitud': 13.398694,
#   'city': 'Berlin',
#   'country': 'DEU'},
#  {'_id': ObjectId('5dd411dbec196ddbed900907'),
#   '': 306,
#   'name': 'SezWho',
#   'category_code': 'tech',
#   'number_of_employees': 9.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Social Network Involvement apps',
#   'total_money_raised': 1000000,
#   'latitud': 37.351894,
#   'longitud': -122.085807,
#   'city': 'Los Altos',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900908'),
#   '': 333,
#   'name': 'Zmags',
#   'category_code': 'tech',
#   'number_of_employees': 95.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Rich-Media Marketing Platform',
#   'total_money_raised': 20800000,
#   'latitud': 55.6839208,
#   'longitud': 12.571492,
#   'city': 'Copenhagen',
#   'country': 'DNK'},
#  {'_id': ObjectId('5dd411dbec196ddbed900909'),
#   '': 339,
#   'name': 'MyBuys',
#   'category_code': 'design',
#   'number_of_employees': 120.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Cross-Channel Personalization',
#   'total_money_raised': 40800000,
#   'latitud': 37.530893,
#   'longitud': -122.245087,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090a'),
#   '': 335,
#   'name': 'Zmags',
#   'category_code': 'tech',
#   'number_of_employees': 95.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Rich-Media Marketing Platform',
#   'total_money_raised': 20800000,
#   'latitud': 51.5111369,
#   'longitud': -0.1247662,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090b'),
#   '': 289,
#   'name': 'blueKiwi',
#   'category_code': 'enterprise',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 12300000,
#   'latitud': 48.8599791,
#   'longitud': 2.3608064,
#   'city': 'Paris',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090c'),
#   '': 318,
#   'name': 'Peer39',
#   'category_code': 'design',
#   'number_of_employees': 50.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Semantic Web Advertising',
#   'total_money_raised': 29900000,
#   'latitud': 40.755446,
#   'longitud': -73.980246,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090d'),
#   '': 325,
#   'name': 'Yedda',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 2500000,
#   'latitud': 32.0554,
#   'longitud': 34.7595,
#   'city': 'Tel Aviv',
#   'country': 'ISR'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090e'),
#   '': 324,
#   'name': 'GotCast',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Entertainment Talent Network',
#   'total_money_raised': 50,
#   'latitud': 34.064139,
#   'longitud': -118.468672,
#   'city': 'Los Angleles',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90090f'),
#   '': 347,
#   'name': 'RealSelf',
#   'category_code': 'tech',
#   'number_of_employees': 23.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 1950000,
#   'latitud': 47.620716,
#   'longitud': -122.347533,
#   'city': 'Seattle',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900910'),
#   '': 340,
#   'name': 'MyBuys',
#   'category_code': 'design',
#   'number_of_employees': 120.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Cross-Channel Personalization',
#   'total_money_raised': 40800000,
#   'latitud': 42.277416,
#   'longitud': -83.733276,
#   'city': 'Ann Arbor',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900911'),
#   '': 366,
#   'name': 'WEbook',
#   'category_code': 'tech',
#   'number_of_employees': 10.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 5000000,
#   'latitud': 38.984172,
#   'longitud': -77.095965,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900912'),
#   '': 389,
#   'name': 'divorce360',
#   'category_code': 'tech',
#   'number_of_employees': 6.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 2500000,
#   'latitud': 26.820375,
#   'longitud': -80.058401,
#   'city': 'North Palm Beach',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900913'),
#   '': 362,
#   'name': 'Entrecard',
#   'category_code': 'tech',
#   'number_of_employees': 1.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'blog advertising network',
#   'total_money_raised': 70,
#   'latitud': 41.355252,
#   'longitud': -72.930855,
#   'city': 'Hamden',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900914'),
#   '': 361,
#   'name': 'Mogreet',
#   'category_code': 'tech',
#   'number_of_employees': 30.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'SMS & MMS Text Message Marketing',
#   'total_money_raised': 14000000,
#   'latitud': 33.999004,
#   'longitud': -118.472297,
#   'city': 'Venice',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900915'),
#   '': 391,
#   'name': 'CrossLoop',
#   'category_code': 'tech',
#   'number_of_employees': 8.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 10500000,
#   'latitud': 36.611645,
#   'longitud': -121.898539,
#   'city': 'Monterey',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900916'),
#   '': 396,
#   'name': 'HubSpot',
#   'category_code': 'tech',
#   'number_of_employees': 650.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'inbound marketing platform',
#   'total_money_raised': 131000000,
#   'latitud': 42.375392,
#   'longitud': -71.118487,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900917'),
#   '': 408,
#   'name': 'Uversity',
#   'category_code': 'social',
#   'number_of_employees': 30.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Social Educational Tools',
#   'total_money_raised': 10200000,
#   'latitud': 37.7749295,
#   'longitud': -122.4194155,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900918'),
#   '': 386,
#   'name': 'Deezer',
#   'category_code': 'music',
#   'number_of_employees': 200.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': "World's first music streaming service",
#   'total_money_raised': 149000000,
#   'latitud': 48.8780596,
#   'longitud': 2.3283853,
#   'city': 'Paris',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900919'),
#   '': 355,
#   'name': 'OurStage',
#   'category_code': 'music',
#   'number_of_employees': 1.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'online avenue for indie musicians',
#   'total_money_raised': 29900000,
#   'latitud': 42.591704,
#   'longitud': -71.319348,
#   'city': 'Chelmsford',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091a'),
#   '': 356,
#   'name': 'GameLayers',
#   'category_code': 'tech',
#   'number_of_employees': 5.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Multiplayer Networked Games',
#   'total_money_raised': 2000000,
#   'latitud': 37.803847,
#   'longitud': -122.402468,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091b'),
#   '': 357,
#   'name': 'Blyk',
#   'category_code': 'tech',
#   'number_of_employees': 100.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Mobile Social Networking',
#   'total_money_raised': 87000000,
#   'latitud': 52.146853,
#   'longitud': -1.721287,
#   'city': 'Helsinki',
#   'country': 'FIN'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091c'),
#   '': 423,
#   'name': 'Shoeboxed',
#   'category_code': 'tech',
#   'number_of_employees': 70.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Painless Receipt & Expense Management',
#   'total_money_raised': 2510000,
#   'latitud': 35.9939,
#   'longitud': -78.8986,
#   'city': 'Durham',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091d'),
#   '': 418,
#   'name': 'HubPages',
#   'category_code': 'tech',
#   'number_of_employees': 21.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Most rewarding place to publish online',
#   'total_money_raised': 8000000,
#   'latitud': 37.7876952,
#   'longitud': -122.3991505,
#   'city': 'San Francisco',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091e'),
#   '': 430,
#   'name': 'Acquia',
#   'category_code': 'enterprise',
#   'number_of_employees': 400.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Enterprise Guide to Drupal',
#   'total_money_raised': 68500000,
#   'latitud': 42.524527,
#   'longitud': -71.137784,
#   'city': 'Burlington',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed90091f'),
#   '': 449,
#   'name': '4Home',
#   'category_code': 'tech',
#   'number_of_employees': 36.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'XML Based Mobile Software Platform',
#   'total_money_raised': 9150000,
#   'latitud': 37.385225,
#   'longitud': -121.991912,
# ...
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Building a smarter web',
#   'total_money_raised': 225,
#   'latitud': 52.3735592,
#   'longitud': 4.8852747,
#   'city': 'Amsterdam',
#   'country': 'NLD'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd0'),
#   '': 5603,
#   'name': 'oneDrum',
#   'category_code': 'enterprise',
#   'number_of_employees': 5.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Real-time collaboration platform',
#   'total_money_raised': 1000000,
#   'latitud': 56.1194238,
#   'longitud': -3.935882,
#   'city': 'Stirling',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd1'),
#   '': 5614,
#   'name': 'Joroto',
#   'category_code': 'tech',
#   'number_of_employees': 3.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'serial idea developers',
#   'total_money_raised': 16,
#   'latitud': 41.701368,
#   'longitud': -81.165981,
#   'city': 'Cleveland',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd2'),
#   '': 5602,
#   'name': 'oneDrum',
#   'category_code': 'enterprise',
#   'number_of_employees': 5.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Real-time collaboration platform',
#   'total_money_raised': 1000000,
#   'latitud': 51.5001524,
#   'longitud': -0.1262362,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd3'),
#   '': 5633,
#   'name': 'Tagmore Solutions',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Mobile Marketing Evolution',
#   'total_money_raised': 225,
#   'latitud': 40.4226918,
#   'longitud': -3.6883074,
#   'city': 'Madrid',
#   'country': 'ESP'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd4'),
#   '': 5650,
#   'name': 'Mint.com',
#   'category_code': 'finance',
#   'number_of_employees': 31.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online personal finance service',
#   'total_money_raised': 31800000,
#   'latitud': 37.392392,
#   'longitud': -122.078727,
#   'city': 'Mountain View',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd5'),
#   '': 5653,
#   'name': 'Lipperhey',
#   'category_code': 'tech',
#   'number_of_employees': 6.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': 'online seo service',
#   'total_money_raised': 180,
#   'latitud': 52.3655578,
#   'longitud': 4.9345824,
#   'city': 'Amsterdam',
#   'country': 'NLD'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd6'),
#   '': 5671,
#   'name': 'CrowdGather',
#   'category_code': 'tech',
#   'number_of_employees': 9.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Network of Online Forum Communities',
#   'total_money_raised': 18000000,
#   'latitud': 34.168955,
#   'longitud': -118.575293,
#   'city': 'Woodland Hills',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd7'),
#   '': 5681,
#   'name': 'Omni-ID',
#   'category_code': 'tech',
#   'number_of_employees': 22.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'passive UHF RFID tags',
#   'total_money_raised': 23000000,
#   'latitud': 37.561111,
#   'longitud': -122.270487,
#   'city': 'Foster City',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd8'),
#   '': 5694,
#   'name': 'Mobiles Republic',
#   'category_code': 'tech',
#   'number_of_employees': 25.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'We publish valuable & personal news apps',
#   'total_money_raised': 9000000,
#   'latitud': 44.8743952,
#   'longitud': -0.5754294,
#   'city': 'Bordeaux Cedex',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bd9'),
#   '': 5695,
#   'name': 'ubigrate',
#   'category_code': 'tech',
#   'number_of_employees': 12.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'modular integration software',
#   'total_money_raised': 450,
#   'latitud': 51.0343624,
#   'longitud': 13.7759644,
#   'city': 'Dresden',
#   'country': 'DEU'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bda'),
#   '': 5696,
#   'name': 'SpectraLinear',
#   'category_code': 'semiconductor',
#   'number_of_employees': 32.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'timing circuits',
#   'total_money_raised': 39000000,
#   'latitud': 37.383777,
#   'longitud': -121.963705,
#   'city': '',
#   'country': 'IND'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bdb'),
#   '': 5697,
#   'name': 'SpectraLinear',
#   'category_code': 'semiconductor',
#   'number_of_employees': 32.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'timing circuits',
#   'total_money_raised': 39000000,
#   'latitud': 30.267153,
#   'longitud': -97.7430608,
#   'city': 'Austin',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bdc'),
#   '': 5708,
#   'name': 'FireScope',
#   'category_code': 'tech',
#   'number_of_employees': 65.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Service Management Software Company',
#   'total_money_raised': 9910000,
#   'latitud': 33.664705,
#   'longitud': -118.012553,
#   'city': 'Huntington Beach',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bdd'),
#   '': 5709,
#   'name': 'FireScope',
#   'category_code': 'tech',
#   'number_of_employees': 65.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Service Management Software Company',
#   'total_money_raised': 9910000,
#   'latitud': 33.0353,
#   'longitud': -96.9274,
#   'city': 'Carrollton',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bde'),
#   '': 5562,
#   'name': 'Spreedly',
#   'category_code': 'enterprise',
#   'number_of_employees': 4.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Billing software',
#   'total_money_raised': 801,
#   'latitud': 35.996497,
#   'longitud': -78.903729,
#   'city': 'Durham',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bdf'),
#   '': 5560,
#   'name': 'Moviepilot',
#   'category_code': 'tech',
#   'number_of_employees': 43.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Personalized movie recommendation',
#   'total_money_raised': 7000000,
#   'latitud': 34.0522342,
#   'longitud': -118.2436849,
#   'city': 'Los Angeles',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be0'),
#   '': 5619,
#   'name': 'Layar',
#   'category_code': 'tech',
#   'number_of_employees': 32.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': 'Augmented Reality',
#   'total_money_raised': 13400000,
#   'latitud': 52.3657578,
#   'longitud': 4.8928722,
#   'city': 'Amsterdam',
#   'country': 'NLD'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be1'),
#   '': 5710,
#   'name': 'FireScope',
#   'category_code': 'tech',
#   'number_of_employees': 65.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Service Management Software Company',
#   'total_money_raised': 9910000,
#   'latitud': -33.867139,
#   'longitud': 151.207114,
#   'city': 'Sydney',
#   'country': 'AUS'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be2'),
#   '': 5581,
#   'name': 'BetKlub',
#   'category_code': 'tech',
#   'number_of_employees': 3.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Social Betting',
#   'total_money_raised': 81,
#   'latitud': 48.8787606,
#   'longitud': 2.3639174,
#   'city': 'Paris',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be3'),
#   '': 5724,
#   'name': 'Maxymiser',
#   'category_code': 'enterprise',
#   'number_of_employees': 250.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Multivariate Testing and Personalization',
#   'total_money_raised': 14000000,
#   'latitud': 55.9485591,
#   'longitud': -3.2151393,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be4'),
#   '': 5711,
#   'name': 'FireScope',
#   'category_code': 'tech',
#   'number_of_employees': 65.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Service Management Software Company',
#   'total_money_raised': 9910000,
#   'latitud': 51.5001524,
#   'longitud': -0.1262362,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be5'),
#   '': 5755,
#   'name': 'Content Syndicate: Words on Demand',
#   'category_code': 'enterprise',
#   'number_of_employees': 15.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'cloud-based content services platform',
#   'total_money_raised': 1500000,
#   'latitud': 25.1910055,
#   'longitud': 55.2373803,
#   'city': 'Dubai',
#   'country': 'ARE'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be6'),
#   '': 5741,
#   'name': 'ChallengePost',
#   'category_code': 'tech',
#   'number_of_employees': 17.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': 'Software challenges and hackathons',
#   'total_money_raised': 4600000,
#   'latitud': 40.7408042,
#   'longitud': -74.00717,
#   'city': 'New York',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be7'),
#   '': 5751,
#   'name': 'StyleCaster',
#   'category_code': 'tech',
#   'number_of_employees': 60.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Media and Ad-Tech for fashion & beauty',
#   'total_money_raised': 5000000,
#   'latitud': 40.7450497,
#   'longitud': -73.9900984,
#   'city': 'New York City',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be8'),
#   '': 5739,
#   'name': 'Solairedirect',
#   'category_code': 'tech',
#   'number_of_employees': 150.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'integrated solar power',
#   'total_money_raised': 26600000,
#   'latitud': 48.8745951,
#   'longitud': 2.3210737,
#   'city': 'Paris',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900be9'),
#   '': 5734,
#   'name': 'Struq',
#   'category_code': 'design',
#   'number_of_employees': 50.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Dynamic Behavioural Advertising',
#   'total_money_raised': 8500000,
#   'latitud': 40.7766412,
#   'longitud': -73.9521468,
#   'city': '',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bea'),
#   '': 5743,
#   'name': 'DeciZium',
#   'category_code': 'tech',
#   'number_of_employees': 12.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Online Decision Technology Innovator',
#   'total_money_raised': 1500000,
#   'latitud': 37.337756,
#   'longitud': -121.89435,
#   'city': 'San Jose',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900beb'),
#   '': 5772,
#   'name': 'Teambox',
#   'category_code': 'tech',
#   'number_of_employees': 35.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': 'Collaboration and file sharing',
#   'total_money_raised': 6750000,
#   'latitud': 41.4063346,
#   'longitud': 2.1920231,
#   'city': 'Barcelona',
#   'country': 'ESP'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bec'),
#   '': 5733,
#   'name': 'Struq',
#   'category_code': 'design',
#   'number_of_employees': 50.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Dynamic Behavioural Advertising',
#   'total_money_raised': 8500000,
#   'latitud': 51.5152023,
#   'longitud': -0.1366861,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bed'),
#   '': 5785,
#   'name': 'Testplant',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'GUI test tool',
#   'total_money_raised': 2560000,
#   'latitud': 51.517356,
#   'longitud': -0.1037742,
#   'city': 'London',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bee'),
#   '': 5798,
#   'name': 'Homesnap',
#   'category_code': 'tech',
#   'number_of_employees': 18.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'online real estate broker',
#   'total_money_raised': 5500000,
#   'latitud': 38.960381,
#   'longitud': -77.084811,
#   'city': 'Washington',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bef'),
#   '': 5803,
#   'name': 'GreenBytes',
#   'category_code': 'enterprise',
#   'number_of_employees': 54.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'Virtual Desktop Storage Systems',
#   'total_money_raised': 35000000,
#   'latitud': 41.829229,
#   'longitud': -71.421059,
#   'city': 'Providence',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf0'),
#   '': 5786,
#   'name': 'Testplant',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'GUI test tool',
#   'total_money_raised': 2560000,
#   'latitud': 40.0230047,
#   'longitud': -105.2532841,
#   'city': 'Boulder',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf1'),
#   '': 5805,
#   'name': 'Culture Jam',
#   'category_code': 'tech',
#   'number_of_employees': 15.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Innovative Social Media Technology',
#   'total_money_raised': 1700000,
#   'latitud': 34.0137151,
#   'longitud': -118.4660597,
#   'city': 'Los Angeles',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf2'),
#   '': 5835,
#   'name': 'Continuity Engine',
#   'category_code': 'tech',
#   'number_of_employees': 11.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Crowdsource Banking',
#   'total_money_raised': 7840000,
#   'latitud': 41.3279176,
#   'longitud': -73.2435522,
#   'city': 'New Haven',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf3'),
#   '': 5823,
#   'name': 'Clavis Technology',
#   'category_code': 'tech',
#   'number_of_employees': 50.0,
#   'founded_year': 2007,
#   'deadpooled_year': 0.0,
#   'description': 'eCommerce Insights & Online Store Audits',
#   'total_money_raised': 3660000,
#   'latitud': 42.3626626,
#   'longitud': -71.084153,
#   'city': 'Cambridge',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf4'),
#   '': 5837,
#   'name': 'Pipit Interactive',
#   'category_code': 'tech',
#   'number_of_employees': 10.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Social Commerce Software',
#   'total_money_raised': 900,
#   'latitud': 34.045499,
#   'longitud': -118.47036,
#   'city': 'Los Angeles',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf5'),
#   '': 5816,
#   'name': 'AgileJ Limited',
#   'category_code': 'tech',
#   'number_of_employees': 3.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'Java Visualization Software',
#   'total_money_raised': 100,
#   'latitud': 51.393654,
#   'longitud': -0.3062632,
#   'city': 'Surbiton',
#   'country': 'GBR'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf6'),
#   '': 5838,
#   'name': 'FundRazr',
#   'category_code': 'social',
#   'number_of_employees': 6.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'Social Commerce Apps',
#   'total_money_raised': 429,
#   'latitud': 49.2843936,
#   'longitud': -123.1092622,
#   'city': 'Vancouver',
#   'country': 'CAN'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf7'),
#   '': 5873,
#   'name': 'Jelli',
#   'category_code': 'enterprise',
#   'number_of_employees': 12.0,
#   'founded_year': 2008,
#   'deadpooled_year': 0.0,
#   'description': 'User-controlled radio',
#   'total_money_raised': 16600000,
#   'latitud': 37.55909,
#   'longitud': -122.321836,
#   'city': 'San Mateo',
#   'country': 'USA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf8'),
#   '': 5872,
#   'name': 'PubliAtis',
#   'category_code': 'tech',
#   'number_of_employees': 10.0,
#   'founded_year': 2006,
#   'deadpooled_year': 0.0,
#   'description': 'SaaS Professional Publishing Software',
#   'total_money_raised': 1000000,
#   'latitud': 48.8699947,
#   'longitud': 2.3406954,
#   'city': 'PARIS',
#   'country': 'FRA'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bf9'),
#   '': 5874,
#   'name': 'Tiny Speck',
#   'category_code': 'tech',
#   'number_of_employees': 45.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': '',
#   'total_money_raised': 17200000,
#   'latitud': 49.2824551,
#   'longitud': -123.109217,
#   'city': 'Vancouver',
#   'country': 'CAN'},
#  {'_id': ObjectId('5dd411dbec196ddbed900bfa'),
#   '': 5890,
#   'name': 'Getyoo',
#   'category_code': 'tech',
#   'number_of_employees': 10.0,
#   'founded_year': 2009,
#   'deadpooled_year': 0.0,
#   'description': 'NFC Events Solutions',
#   'total_money_raised': 1130000,
#   'latitud': 50.83997,
#   'longitud': 4.3464721,
#   'city': 'Brussels',
#   'country': 'BEL'}]

# %%
def getLocation(emp):
    location = []
    longitude = emp['latitud']
    latitude = emp['longitud']
    loc = {
        'type':'Point',
        'coordinates':[float(longitude), float(latitude)]
    }
    location.append(loc)
    return location

# %%
getLocation(empresas[1])
# Out:
# [{'type': 'Point', 'coordinates': [37.778613, -122.395289]}]

# %%
for empresa in empresas:
    value={"$set": {'location' : getLocation(empresa)}}
    coll.update_one(empresa,value)

# %%
# Out:
# <class 'dict'>
